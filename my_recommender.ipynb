# %%
import goodreads_recommender

# %%
interactions, my_books, book_titles = goodreads_recommender.init_data(
    liked_books="my_liked_books.csv",
    book_id_map="book_id_map.csv",
    interactions="goodreads_interactions.csv",
    book_titles="book_titles.json",
)

# %%
goodreads_recommender.show_recommendation(interactions, my_books, book_titles)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2f009">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f009_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_2f009_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_2f009_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_2f009_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_2f009_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_2f009_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_2f009_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_2f009_level0_col7" class="col_heading level0 col7" >title_clean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f009_level0_row0" class="row_heading level0 row0" >4015</th>
#       <td id="T_2f009_row0_col0" class="data row0 col0" >25147754</td>
# ...
